# %% [markdown]
# <a href="https://colab.research.google.com/github/yash5891/Python-Programming-Assignments/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df["Risk"]
# Out:
# 0          Risk 1 (High)
# 1           Risk 3 (Low)
# 2          Risk 1 (High)
# 3          Risk 1 (High)
# 4          Risk 1 (High)
#               ...
# 24058    Risk 2 (Medium)
# 24059       Risk 3 (Low)
# 24060       Risk 3 (Low)
# 24061       Risk 3 (Low)
# 24062       Risk 3 (Low)
# Name: Risk, Length: 24063, dtype: object

# %%
v=df[["DBA Name","Risk","Address","Results"]]
v.head()
# Out:
#                     DBA Name           Risk               Address    Results
# 0               DANY'S TACOS  Risk 1 (High)  2857 S ST LOUIS AVE        Fail
# 1      BILLY FOOD MARKET INC   Risk 3 (Low)  3906 W ROOSEVELT RD   Not Ready
# 2  TAQUERIA HACIENDA TAPATIA  Risk 1 (High)       4125 W 26TH ST        Pass
# 3     WILD GOOSE BAR & GRILL  Risk 1 (High)   4265 N LINCOLN AVE        Fail
# 4         PUBLICAN TAVERN K1  Risk 1 (High)    11601 W TOUHY AVE        Fail

# %%
v=df[["Risk","Results"]]

# %%
v
# Out:
#                   Risk    Results
# 0        Risk 1 (High)       Fail
# 1         Risk 3 (Low)  Not Ready
# 2        Risk 1 (High)       Pass
# 3        Risk 1 (High)       Fail
# 4        Risk 1 (High)       Fail
# ...                ...        ...
# 24058  Risk 2 (Medium)       Pass
# 24059     Risk 3 (Low)       Pass
# 24060     Risk 3 (Low)       Pass
# 24061     Risk 3 (Low)       Pass
# 24062     Risk 3 (Low)       Pass
#
# [24063 rows x 2 columns]

# %%
dff.loc[["WILD GOOSE BAR & GRILL","TAQUERIA HACIENDA TAPATIA"],["Risk","Results"]]
# Out:
#                                     Risk Results
# DBA Name
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Fail
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)    Pass

# %%
dff = df.set_index("DBA Name")

# %%
dff
# Out:
#                         DBA Name  Facility Type             Risk  \
# 0                   DANY'S TACOS     Restaurant    Risk 1 (High)
# 1          BILLY FOOD MARKET INC            NaN     Risk 3 (Low)
# 2      TAQUERIA HACIENDA TAPATIA     Restaurant    Risk 1 (High)
# 3         WILD GOOSE BAR & GRILL     Restaurant    Risk 1 (High)
# 4             PUBLICAN TAVERN K1     Restaurant    Risk 1 (High)
# ...                          ...            ...              ...
# 24058               FRESH PANTRY  Grocery Store  Risk 2 (Medium)
# 24059                     BUTTER            NaN     Risk 3 (Low)
# 24060    SAFAH FOOD & LIQUOR INC  Grocery Store     Risk 3 (Low)
# 24061            RAINBOW GROCERY  Grocery Store     Risk 3 (Low)
# 24062                 MAKIA FOOD            NaN     Risk 3 (Low)
#
#                       Address      Zip Inspection Date        Inspection Type  \
# 0        2857 S ST LOUIS AVE   60623.0      03/27/2017                License
# ...

# %%
dff.loc[["SCRUB A DUB"],["Risk"]]
# Out:
#                         Risk
# DBA Name
# SCRUB A DUB  Risk 2 (Medium)

# %%
dff.loc["THRESHOLD SCHOOL":"SCRUB A DUB":3000,"Inspection Type":]
# Out:
#                                Inspection Type             Results
# DBA Name
# THRESHOLD SCHOOL                       Canvass                Pass
# SAN JOSE FAST FOOD                     Canvass     Out of Business
# CHUCHOS ON ADDISON INC                 Canvass  Pass w/ Conditions
# PIZZERIA AROMA           Canvass Re-Inspection                Pass
# JEWEL FOOD STORE #3210                 Canvass            No Entry
# EGANS TAVERN                           Canvass     Out of Business
# Los Amigos Grill                       Canvass     Out of Business
# JOHNNY VAN'S SMOKEHOUSE                License                Pass
# WEN   CAFE INC                 Out of Business                Fail

# %%
dff.iloc[500:511]
# Out:
#                                   Facility Type             Risk  \
# DBA Name
# THE MECCA RESTAURANT                 Restaurant    Risk 1 (High)
# L & T CHINA FAST WOK INC.            Restaurant    Risk 1 (High)
# SCHNEIDER  SENIOR  APARTMENT       Golden Diner    Risk 1 (High)
# ECKHARDT CAFE                        Restaurant    Risk 1 (High)
# WING ZONE                            Restaurant    Risk 1 (High)
# ARBYS                                Restaurant    Risk 1 (High)
# LAS ISLAS MARIAS                     Restaurant    Risk 1 (High)
# MARGARET'S                           Restaurant    Risk 1 (High)
# POPEYES FAMOUS FRIED CHICKEN         Restaurant  Risk 2 (Medium)
# PJ PIZZA COMPANY 1 DBA PAPA JOHNS    Restaurant  Risk 2 (Medium)
# DUNKIN DONUTS                        Restaurant  Risk 2 (Medium)
#
#                                                    Address      Zip  \
# DBA Name
# THE MECCA RESTAURANT                 6666 N NORTHWEST HWY   60631.0
# ...

# %%
v=dff.iloc[[100,1000,10000],[5,3,1]]

v
# Out:
#                            Inspection Type      Zip           Risk
# DBA Name
# TAQUERIA LA CANTERA                License  60608.0  Risk 1 (High)
# PARK TAVERN CHICAGO              Complaint  60612.0  Risk 1 (High)
# LITTLE VILLAGE HIGH SCHOOL         Canvass  60623.0  Risk 1 (High)

# %%
dff.loc[["ARBYS" ,"POPEYES FAMOUS FRIED CHICKEN"]]
# Out:
#                              Facility Type             Risk  \
# DBA Name
# ARBYS                           Restaurant    Risk 1 (High)
# POPEYES FAMOUS FRIED CHICKEN    Restaurant  Risk 2 (Medium)
#
#                                             Address      Zip Inspection Date  \
# DBA Name
# ARBYS                             500 W MADISON ST   60661.0      03/14/2017
# POPEYES FAMOUS FRIED CHICKEN  9516 S VINCENNES AVE   60643.0      03/14/2017
#
#                              Inspection Type             Results
# DBA Name
# ARBYS                                Canvass                Pass
# POPEYES FAMOUS FRIED CHICKEN       Complaint  Pass w/ Conditions

# %%
ef = pd.read_csv(r'/content/employee.csv')
ef.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-21c2cc98be49> in <cell line: 1>()
# ----> 1 ef = pd.read_csv(r'/content/employee.csv')
#       2 ef.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
sf= pd.read_csv(r"/content/stackoverflow_qa.csv")
sf.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# ...

# %%
sf.loc["quest_name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0d5a36307597> in <cell line: 1>()
# ----> 1 sf.loc["quest_name"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
# ...

# %%
a =sf[sf["answercount"]==5]
a["quest_name"]
# Out:
# 75               saveenr
# 115         Uri Laserson
# 130                 BFTM
# 189        Boris Gorelik
# 246               turtle
#               ...
# 53433                pyd
# 53752    ConstantLearner
# 53983           Steve Xu
# 54384     Baron Yugovich
# 55444               Alex
# Name: quest_name, Length: 296, dtype: object

# %%
sf.loc[sf["answercount"]==5, 'quest_name' ]
# Out:
# 75               saveenr
# 115         Uri Laserson
# 130                 BFTM
# 189        Boris Gorelik
# 246               turtle
#               ...
# 53433                pyd
# 53752    ConstantLearner
# 53983           Steve Xu
# 54384     Baron Yugovich
# 55444               Alex
# Name: quest_name, Length: 296, dtype: object

# %%
sf.loc[sf["viewcount"]>10, 'quest_name' ]
# Out:
# 0               yueerhu
# 1        Jason Strimpel
# 2        Jason Strimpel
# 3            user814005
# 4          Uri Laserson
#               ...
# 56393              xxyy
# 56394             Ajeet
# 56395              NthA
# 56396           Fan LUO
# 56397     Soorya Paturi
# Name: quest_name, Length: 56355, dtype: object

# %%
# sf.loc[sf["quest_name"]=="ans_name" ]
[sf['quest_name'], ]
# Out:
# [26       Jon Clements
#  51               John
#  99             Ross R
#  101           tshauck
#  112           JD Long
#               ...
#  55334       sheldonzy
#  55359     Dinosaurius
#  55449     Akhil Reddy
#  55484      magicsword
#  55815    thomas2013ch
#  Name: quest_name, Length: 2240, dtype: object]

# %%
import numpy as np



sf.loc[(sf["score"]>100)&(sf["ans_name"].isnull())]
# Out:
#             id         creationdate  score  viewcount  \
# 184   11350770  2012-07-05 18:57:34    149     155776
# 514   13148429  2012-10-30 22:22:59    312     228357
# 527   13187778  2012-11-02 00:57:33    102     202329
# 560   13331698  2012-11-11 13:48:53    154     174964
# 5013  19377969  2013-10-15 09:42:52    128     144045
# 5370  20845213  2013-12-30 18:24:25    130      61332
# 8289  26266362  2014-10-08 21:00:19    132     108655
#
#                                                   title  answercount  \
# 184       pandas + dataframe - select by partial string            7
# 514       How to change the order of DataFrame columns?           19
# 527   Convert pandas dataframe to numpy array, prese...            8
# 560   How to apply a function to two columns of Pand...            9
# 5013  Combine two columns of text in dataframe in pa...           10
# 5370  How to avoid Python/Pandas creating an index i...            3
# ...

# %%
d=sf.loc[sf["quest_rep"]>sf["ans_rep"],["quest_name"]]

# sf
# len(d)/len(sf)
# Out:
# 1.0

# %%
sf.loc[sf['answercount']==2  , "answercount"]
# Out:
# 26       2
# 182      2
# 255      2
# 311      2
# 331      2
#         ..
# 55259    2
# 55329    2
# 55334    2
# 55359    2
# 55449    2
# Name: answercount, Length: 680, dtype: int64

# %%
sf.loc[26,:]
# Out:
# id                                         9588331
# creationdate                   2012-03-06 17:01:47
# score                                           22
# viewcount                                    10038
# title            Simple cross-tabulation in pandas
# answercount                                      2
# commentcount                                     3
# favoritecount                                  5.0
# quest_name                            Jon Clements
# quest_rep                                  85944.0
# ans_name                         Jeff Hammerbacher
# ans_rep                                     3172.0
# Name: 26, dtype: object

# %%
sf.loc[26:,:]
# Out:
#              id         creationdate  score  viewcount  \
# 26      9588331  2012-03-06 17:01:47     22      10038
# 27      9597681  2012-03-07 07:56:37      3       3060
# 28      9621362  2012-03-08 16:42:30      7       6417
# 29      9641916  2012-03-09 22:36:52      7       5519
# 30      9647656  2012-03-10 15:35:26      3        986
# ...         ...                  ...    ...        ...
# 56393  47606711  2017-12-02 10:07:13      0         17
# 56394  47607549  2017-12-02 11:41:59     -1         41
# 56395  47609325  2017-12-02 15:16:26      0         33
# 56396  47609598  2017-12-02 15:45:40      2         18
# 56397  47611969  2017-12-02 19:59:09     -6         19
#
#                                                    title  answercount  \
# 26                     Simple cross-tabulation in pandas            2
# 27                read_csv converters for unkown columns            1
# 28     how do I compute a weighted moving average usi...            1
# ...

# %%
e=sf.loc[(sf["answercount"]>5)&(sf["answercount"]<10)]
e.loc[(sf["viewcount"]<1000)]
# Out:
#              id         creationdate  score  viewcount  \
# 4958   19892107  2013-11-10 16:28:50      5        385
# 5339   21040578  2014-01-10 09:33:09     -1        175
# 10934  29407945  2015-04-02 08:04:51      8        997
# 20980  35329206  2016-02-11 01:25:41      2         91
# 21442  35212206  2016-02-04 21:43:11      0        149
# 22320  36926119  2016-04-28 21:51:14      9        392
# 22917  37874936  2016-06-17 06:50:06      9        881
# 22956  36986482  2016-05-02 15:47:25      2         85
# 23453  37232387  2016-05-14 22:05:45      2        222
# 24851  38902239  2016-08-11 17:01:57     13        380
# 24968  38733719  2016-08-03 03:07:31     12        801
# 25067  37992585  2016-06-23 13:07:35      0        407
# 27240  38681821  2016-07-31 07:37:37      7        365
# 27825  39054413  2016-08-20 12:56:48      2        513
# 27984  39353215  2016-09-06 15:56:18      4        811
# 30515  40090522  2016-10-17 15:40:08      5        262
# ...

# %%
e=sf.loc[(sf["answercount"]>5)&(sf["answercount"]<10)&(sf["viewcount"]<1000)]
e
# Out:
#              id         creationdate  score  viewcount  \
# 4958   19892107  2013-11-10 16:28:50      5        385
# 5339   21040578  2014-01-10 09:33:09     -1        175
# 10934  29407945  2015-04-02 08:04:51      8        997
# 20980  35329206  2016-02-11 01:25:41      2         91
# 21442  35212206  2016-02-04 21:43:11      0        149
# 22320  36926119  2016-04-28 21:51:14      9        392
# 22917  37874936  2016-06-17 06:50:06      9        881
# 22956  36986482  2016-05-02 15:47:25      2         85
# 23453  37232387  2016-05-14 22:05:45      2        222
# 24851  38902239  2016-08-11 17:01:57     13        380
# 24968  38733719  2016-08-03 03:07:31     12        801
# 25067  37992585  2016-06-23 13:07:35      0        407
# 27240  38681821  2016-07-31 07:37:37      7        365
# 27825  39054413  2016-08-20 12:56:48      2        513
# 27984  39353215  2016-09-06 15:56:18      4        811
# 30515  40090522  2016-10-17 15:40:08      5        262
# ...

# %%
e=sf.loc[(sf["answercount"]>5)&(sf["answercount"]<10)&(sf["viewcount"]>1000)]
e
# Out:
#              id         creationdate  score  viewcount  \
# 8       7837722  2011-10-20 14:46:14    201     223746
# 24      9555635  2012-03-04 14:25:36     19       6604
# 35      9758450  2012-03-18 12:53:06     42      43262
# 42      9850954  2012-03-24 10:26:50     14       4498
# 87     10511024  2012-05-09 06:45:29     71      48836
# ...         ...                  ...    ...        ...
# 30963  40532024  2016-11-10 16:06:47     10       1549
# 31536  40553560  2016-11-11 17:53:07      5       1697
# 39850  43408621  2017-04-14 09:13:05      2       3414
# 40550  43387467  2017-04-13 08:43:24      4       1122
# 42009  44327999  2017-06-02 11:38:06      3       4007
#
#                                                    title  answercount  \
# 8      What is the most efficient way to loop through...            8
# 24              Open source Enthought Python alternative            8
# 35           Pandas convert dataframe to array of tuples            7
# ...

# %%
ed=pd.read_csv(r"/content/employee.csv")
ed.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
ed['RACE'].unique()
# Out:
# array(['Hispanic/Latino', 'White', 'Black or African American',
#        'Asian/Pacific Islander', nan, 'American Indian or Alaskan Native',
#        'Others'], dtype=object)

# %%
female=ed['DEPARTMENT']=='Houston Police Department-HPD'
race=ed["RACE"]=="Black or African American"
g=ed["GENDER"]=="Female"
ed[female & race & g ]
# Out:
#       UNIQUE_ID             POSITION_TITLE                     DEPARTMENT  \
# 55           55   ADMINISTRATIVE ASSOCIATE  Houston Police Department-HPD
# 113         113      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 137         137             JAIL ATTENDANT  Houston Police Department-HPD
# 196         196      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 228         228      FINANCIAL ANALYST III  Houston Police Department-HPD
# ...         ...                        ...                            ...
# 1940       1940      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 1949       1949             POLICE OFFICER  Houston Police Department-HPD
# 1955       1955             JAIL ATTENDANT  Houston Police Department-HPD
# 1964       1964  ADMINISTRATIVE SPECIALIST  Houston Police Department-HPD
# 1978       1978     POLICE SERVICE OFFICER  Houston Police Department-HPD
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# ...

# %%
ed[(ed['DEPARTMENT']=='Houston Police Department-HPD')& (ed["RACE"]=="Black or African American")&(ed["GENDER"]=="Female")]
# Out:
#       UNIQUE_ID             POSITION_TITLE                     DEPARTMENT  \
# 55           55   ADMINISTRATIVE ASSOCIATE  Houston Police Department-HPD
# 113         113      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 137         137             JAIL ATTENDANT  Houston Police Department-HPD
# 196         196      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 228         228      FINANCIAL ANALYST III  Houston Police Department-HPD
# ...         ...                        ...                            ...
# 1940       1940      SENIOR POLICE OFFICER  Houston Police Department-HPD
# 1949       1949             POLICE OFFICER  Houston Police Department-HPD
# 1955       1955             JAIL ATTENDANT  Houston Police Department-HPD
# 1964       1964  ADMINISTRATIVE SPECIALIST  Houston Police Department-HPD
# 1978       1978     POLICE SERVICE OFFICER  Houston Police Department-HPD
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# ...

# %%
ed['DEPARTMENT']=='Houston Police Department-HPD'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1995     True
# 1996    False
# 1997     True
# 1998     True
# 1999    False
# Name: DEPARTMENT, Length: 2000, dtype: bool

# %%
d=ed.loc[(ed["GENDER"]=="Female") | (ed["GENDER"]=="Male") & (ed["BASE_SALARY"]=="100000")]
d
# Out:
#       UNIQUE_ID                   POSITION_TITLE  \
# 0             0      ASSISTANT DIRECTOR (EX LVL)
# 1             1                LIBRARY ASSISTANT
# 35           35                 DENTAL ASSISTANT
# 36           36                 SENIOR INSPECTOR
# 38           38     SENIOR MICROCOMPUTER ANALYST
# ...         ...                              ...
# 1976       1976       SENIOR SIDELOADER OPERATOR
# 1978       1978           POLICE SERVICE OFFICER
# 1983       1983        ADMINISTRATIVE SPECIALIST
# 1990       1990  BUILDING MAINTENANCE SUPERVISOR
# 1991       1991         MOBILITY SERVICE OFFICER
#
#                           DEPARTMENT  BASE_SALARY                       RACE  \
# 0        Municipal Courts Department     121862.0            Hispanic/Latino
# 1                            Library      26125.0            Hispanic/Latino
# 35           Health & Human Services      34923.0  Black or African American
# ...

# %%
d=ed.loc[ (ed["GENDER"]=="Male") & (ed["BASE_SALARY"]>100000),["RACE","GENDER","BASE_SALARY"]]


d
# Out:
#                            RACE GENDER  BASE_SALARY
# 8                         White   Male     107962.0
# 11    Black or African American   Male     180416.0
# 43              Hispanic/Latino   Male     165216.0
# 169                       White   Male     120916.0
# 178                       White   Male     210588.0
# 186                       White   Male     110881.0
# 217      Asian/Pacific Islander   Male     102019.0
# 297                       White   Male     141948.0
# 299   Black or African American   Male     100228.0
# 416                       White   Male     104455.0
# 561                       White   Male     125884.0
# 593   Black or African American   Male     275000.0
# 708   Black or African American   Male     130585.0
# 713                       White   Male     120750.0
# 719      Asian/Pacific Islander   Male     163228.0
# 767                       White   Male     199596.0
# 855   Black or African American   Male     186192.0
# ...

# %%
(ed["BASE_SALARY"]=="100000")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: BASE_SALARY, Length: 2000, dtype: bool

# %%
import pandas as pd
df2=pd.read_csv(r"/content/employee_sample.csv")
df2.head()
# Out:
#   Unnamed: 0  GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# 0        Tom    Male  White         Engineering                23  107962
# 1       Niko    Male  Black         Engineering                 1   30347
# 2   Penelope  Female  White         Engineering                12   60258
# 3       Aria  Female  Black         Engineering                 8   43618
# 4      Sofia  Female  Black  Parks & Recreation                23   26125

# %%
df2['bouncer']=[2,3,4,5,6,7,8]
df2
# Out:
#   Unnamed: 0  GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# 0        Tom    Male  White         Engineering                23  107962
# 1       Niko    Male  Black         Engineering                 1   30347
# 2   Penelope  Female  White         Engineering                12   60258
# 3       Aria  Female  Black         Engineering                 8   43618
# 4      Sofia  Female  Black  Parks & Recreation                23   26125
# 5       Dean    Male  Black  Parks & Recreation                 3   33592
# 6       Zach    Male  White  Parks & Recreation                 4   37565
#
#    bouncer
# 0        2
# 1        3
# 2        4
# 3        5
# 4        6
# 5        7
# 6        8

# %%
df2.dataframe(coloumns=["Unnamed: 0","GENDER","RACE","DEPARTMENT","YEARS EXPERIENCE","SALARY"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0f057277afbc> in <cell line: 1>()
# ----> 1 df2.dataframe(coloumns=["Unnamed: 0","GENDER","RACE","DEPARTMENT","YEARS EXPERIENCE","SALARY"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dataframe'

# %%
df2.set_index('Unnamed: 0',inplace=True)

# %%
df2
# Out:
#             GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom           Male  White         Engineering                23  107962
# Niko          Male  Black         Engineering                 1   30347
# Penelope    Female  White         Engineering                12   60258
# Aria        Female  Black         Engineering                 8   43618
# Sofia       Female  Black  Parks & Recreation                23   26125
# Dean          Male  Black  Parks & Recreation                 3   33592
# Zach          Male  White  Parks & Recreation                 4   37565
#
#             bouncer
# Unnamed: 0
# Tom               2
# Niko              3
# Penelope          4
# Aria              5
# Sofia             6
# Dean              7
# Zach              8

# %%
df2['a'] = 9
df2
# Out:
#             GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom           Male  White         Engineering                23  107962
# Niko          Male  Black         Engineering                 1   30347
# Penelope    Female  White         Engineering                12   60258
# Aria        Female  Black         Engineering                 8   43618
# Sofia       Female  Black  Parks & Recreation                23   26125
# Dean          Male  Black  Parks & Recreation                 3   33592
# Zach          Male  White  Parks & Recreation                 4   37565
#
#             bouncer  a
# Unnamed: 0
# Tom               2  9
# Niko              3  9
# Penelope          4  9
# Aria              5  9
# Sofia             6  9
# Dean              7  9
# Zach              8  9

# %%
import numpy as np
df2['b'] = np.random.randint(1,10,7)
df2
# Out:
#             GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom           Male  White         Engineering                23  107962
# Niko          Male  Black         Engineering                 1   30347
# Penelope    Female  White         Engineering                12   60258
# Aria        Female  Black         Engineering                 8   43618
# Sofia       Female  Black  Parks & Recreation                23   26125
# Dean          Male  Black  Parks & Recreation                 3   33592
# Zach          Male  White  Parks & Recreation                 4   37565
#
#             bouncer  a  b
# Unnamed: 0
# Tom               2  9  5
# Niko              3  9  7
# Penelope          4  9  5
# Aria              5  9  8
# Sofia             6  9  3
# Dean              7  9  6
# Zach              8  9  7

# %%
df2
# Out:
#             GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom           Male  White         Engineering                23  107962
# Niko          Male  Black         Engineering                 1   30347
# Penelope    Female  White         Engineering                12   60258
# Aria        Female  Black         Engineering                 8   43618
# Sofia       Female  Black  Parks & Recreation                23   26125
# Dean          Male  Black  Parks & Recreation                 3   33592
# Zach          Male  White  Parks & Recreation                 4   37565
#
#             bouncer  a  b
# Unnamed: 0
# Tom               2  9  5
# Niko              3  9  7
# Penelope          4  9  5
# Aria              5  9  8
# Sofia             6  9  3
# Dean              7  9  6
# Zach              8  9  7

# %%
df2.loc[(df2["YEARS EXPERIENCE"]>5),'bouncer']=0
df2
# Out:
#             GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom           Male  White         Engineering                23  107962
# Niko          Male  Black         Engineering                 1   30347
# Penelope    Female  White         Engineering                12   60258
# Aria        Female  Black         Engineering                 8   43618
# Sofia       Female  Black  Parks & Recreation                23   26125
# Dean          Male  Black  Parks & Recreation                 3   33592
# Zach          Male  White  Parks & Recreation                 4   37565
#
#             bouncer  a  b
# Unnamed: 0
# Tom               0  9  5
# Niko              3  9  7
# Penelope          0  9  5
# Aria              0  9  8
# Sofia             0  9  3
# Dean              7  9  6
# Zach              8  9  7

# %%
df2.loc[ (df2["DEPARTMENT"]=="Engineering") &(df2["GENDER"]=="Female")  ,"a"	]=89
df2
# Out:
#             GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom           Male  White         Engineering                23  107962
# Niko          Male  Black         Engineering                 1   30347
# Penelope    Female  White         Engineering                12   60258
# Aria        Female  Black         Engineering                 8   43618
# Sofia       Female  Black  Parks & Recreation                23   26125
# Dean          Male  Black  Parks & Recreation                 3   33592
# Zach          Male  White  Parks & Recreation                 4   37565
#
#             bouncer   a  b
# Unnamed: 0
# Tom               0   9  5
# Niko              3   9  7
# Penelope          0  89  5
# Aria              0  89  8
# Sofia             0   9  3
# Dean              7   9  6
# Zach              8   9  7

# %%
df2.loc[(df2['GENDER']=='Male')]
# Out:
#            GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Unnamed: 0
# Tom          Male  White         Engineering                23  107962
# Niko         Male  Black         Engineering                 1   30347
# Dean         Male  Black  Parks & Recreation                 3   33592
# Zach         Male  White  Parks & Recreation                 4   37565
#
#             bouncer  a  b
# Unnamed: 0
# Tom               0  9  5
# Niko              3  9  7
# Dean              7  9  6
# Zach              8  9  7
